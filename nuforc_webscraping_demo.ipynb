# %% [markdown]
# **Created by: Christopher Brown**
# **Last revised: 9/13/20**

# %% [markdown]
# # Overview
# This notebook provides the Python code and functions I created to acquire 94,000+ UFO reports from nuforc.org. In order to web scrape an individual report which contains the corresponding full report summary, three distinct scrapes are necessary.

# %%
# Import necessary libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
# import numpy as np 
# pip install lxml # for pd.read_html()
# pip install html5lib
import time # time.time() for tracking time spent on large scrapes

# Code for more robust scraping/fault tolerance (necessary for level 3 scraping due to the long duration)
# Acquired via: https://findwork.dev/blog/advanced-usage-python-requests-timeouts-retries-hooks/
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

retry_strategy = Retry(
    total=5,
    status_forcelist=[429, 500, 502, 503, 504],
    method_whitelist=["HEAD", "GET", "OPTIONS"]
)
adapter = HTTPAdapter(max_retries=retry_strategy)
http = requests.Session()
http.mount("https://", adapter)
http.mount("http://", adapter)

# %% [markdown]
# # First level scraping
# The primary goal of the first level scrape is to gather a list of urls for each month/year combination on the [web reports page](http://www.nuforc.org/webreports/ndxevent.html).

# %%
# 1st level scraping function
def nuforc_scrape_L1(url='http://www.nuforc.org/webreports/ndxevent.html'):
    """
    Scrape the National UFO Reporting Center Report Index by Month.
    
    Returns:
    dict of urls and corresponding month/year and report count in a tuple
    
    Example usage:
    nuforc_scrape_L1()
    """
    # Generate the request
    page = requests.get(url, timeout=10)
    if page: # Handle new scrape / page
        soup = BeautifulSoup(page.content, 'html.parser')
    else: # Return a helpful message if no valid input has been supplied.
        return 'Please provide a valid url leading to an html page.'
    
    table = soup.find('tbody')
    
    url_dict = {} # Build a dict as follows: {url: (date, count)}
    for t in table.find_all('tr'):
        date,count = t.find_all('td')
        url_dict[date.find('a')['href']] = (date.text, count.text)
    return url_dict

# %%
# Run the first scrape
url_dict_L1 = nuforc_scrape_L1()

# %% [markdown]
# # Second and third level scraping
# Next, visiting each month/year url is necessary in order to extract the report table at each location. However, because the `Summary` field is truncated at 135 characters, it is also necessary to retrieve the url for each sighting page, where the full `Summary` can be extracted.
#
# Because using the 3rd level scrape on all month/year urls can take a considerable amount of time, I designed the workflow to allow passage of a partial month/year url list, allowing for some control over the run time as well as the volume of records returned.

# %%
# Note that the urls begin with 'http://www.nuforc.org/webreports/
urls = ['http://www.nuforc.org/webreports/'+k for k in url_dict_L1.keys()]
len(urls) # 865 month/year urls as of 9/8/2020
# Out:
# 865

# %% [markdown]
# Pandas has a handy `read_html()` function for extracting html tables, which is very useful for the level 2 scrape. In the next cell, I'll run it on an example of the most recent entry (09/2020 as of this writing) to give a sense of what the raw results look like. As nice as this is, it doesn't return the individual report urls, so that extraction needs to be done with the help of `BeautifulSoup`.

# %%
# Pass the first (most recent) url, extract first and only html table,
# then take a look at the resulting dataframe
df = pd.read_html(urls[0])[0]
df
# Out:
#      Date / Time                        City State      Shape       Duration  \
# 0   9/4/20 05:36                     Buffalo    NY      Other        Unknown
# 1   9/4/20 04:58                    Lakeland    FL   Fireball      4 seconds
# 2   9/4/20 03:20                 York County    VA      Other    1-2 seconds
# 3   9/4/20 03:18         Beausejour (Canada)    MB  Formation      5 seconds
# 4   9/4/20 01:15                     Pahrump    NV      Light    2-3 minutes
# 5   9/4/20 01:00                Williamstown    WV   Teardrop        Seconds
# 6   9/3/20 23:45                       Allen    TX       Oval      5 seconds
# 7   9/3/20 23:42                    Granbury    TX      Light    5-6 seconds
# 8   9/3/20 21:15                   Mukwonago    WI   Triangle      2 minutes
# 9   9/3/20 20:00             Dansville/Mason    MI      Light     10 seconds
# 10  9/3/20 13:30                      Tacoma    WA   Fireball    3-4 minutes
# 11  9/3/20 01:30                     Roanoke    TX      Light      8 seconds
# 12  9/2/20 21:45         Coronation (Canada)    AB     Sphere      2 minutes
# 13  9/2/20 21:15                     Redvale    CO      Light     20 minutes
# 14  9/2/20 20:40  Indianford/Fulton/Edgerton    WI   Triangle  45-60 seconds
# 15  9/2/20 19:39                    Cheyenne    WY      Other     70 minutes
# 16  9/2/20 18:00                    Florence    CO     Sphere      5 seconds
# 17  9/2/20 16:30                  Fort Worth    TX     Sphere           Hour
# 18  9/2/20 15:03                  New Albany    OH       Cone       1 minute
# 19  9/2/20 11:00                        Otis    OR      Other    15 minutes?
# 20  9/2/20 10:52      Naches Peak Loop Trail    WA     Circle      >1 minute
# 21  9/2/20 03:40                Liberty Lake    WA   Changing         1 hour
# 22  9/2/20 02:35                    Temecula    CA      Light          Hours
# 23  9/2/20 01:00           Smolensk (Russia)   NaN      Light     30 minutes
# 24  9/2/20 01:00                Newport News    VA   Changing     40 minutes
# 25  9/1/20 22:15                     Parrish    FL   Fireball      5 seconds
# 26  9/1/20 05:00                        Hull    MA      Light     30 minutes
# 27  9/1/20 04:20                    Edmonton    AB      Light      3 minutes
# 28  9/1/20 03:00                        Ames    IA      Light      2 seconds
# 29  9/1/20 01:07                 McMinnville    OR   Teardrop      2 seconds
# 30  9/1/20 00:25                   La Quinta    CA  Formation    3-5 seconds
#
#                                               Summary  Posted
# 0   The shape consisted of two chevrons with a ver...  9/4/20
# 1   Bright Falling Green Object In A Moonlit Early...  9/4/20
# 2   I was heading back from a friends house coming...  9/4/20
# 3       3 white dots flying East ward in Eastern sky.  9/4/20
# 4   Blue ziggzaging and sudden stops light that ti...  9/4/20
# 5   Looked up and caught a glimpse of a light movi...  9/4/20
# 6   Large oval shaped bright green ufo traveling t...  9/4/20
# 7   I was watching the East sky by lake Granbury a...  9/4/20
# 8            Triangle with 3 white lights on corners.  9/4/20
# 9                           Triple lights in the sky.  9/4/20
# 10  I was sitting out side at 1:30 am smoking a ci...  9/4/20
# 11                                  Green oval lights  9/4/20
# 12  Looked out window to the east to see if Mars w...  9/4/20
# 13  Blinking red light, low on horizon, flashing, ...  9/4/20
# 14  4 large white lights with 2 on either side (cr...  9/4/20
# 15  Cloud-seeding irregular movement object seen n...  9/4/20
# 16  Bright white sphere surrounded by an orange gl...  9/4/20
# 17  2 black spheres hovering over fort worth. Mult...  9/4/20
# 18  Driving down 88 coming up to 22 and seen 2 con...  9/4/20
# 19         Invisible object caught in photo with orbs  9/4/20
# 20  Oreo-Like Circular Metallic Flying Object and ...  9/4/20
# 21  A very bright constantly changing starlike lig...  9/4/20
# 22  I had let my dog outside to go potty in the mi...  9/4/20
# 23  moving light, radiant balls going up and down,...  9/4/20
# 24  A bright moonlit night with no stars to see, e...  9/4/20
# 25                   UFO sighting in parrish Florida.  9/4/20
# 26  solid object with the bank of strobing lights ...  9/4/20
# 27  I was riding my pedal bike to the 711 in st.al...  9/4/20
# 28  Light in sky defying gravity and disappearing ...  9/4/20
# 29  White with blueish hint comet looking thing fl...  9/4/20
# 30   HIGH SPEED BRIGHT WHITE OBJECTS PASSING OVERHEAD  9/4/20

# %%
def nuforc_scrape_L2(monthly_urls):
    """
    Scrapes a list of urls retrieved from the National UFO Reporting Center Report
    Index by month/year pair. See http://www.nuforc.org/webreports/ndxevent.html. From each url
    an html table is extracted and stored as a dataframe.
    
    Additionally, this function calls upon nuforc_scrape_L3() as a 3rd level scrape,
    extracting the full summary for each sighting and adding the text to the corresponding
    report/dataframe.
    
    Returns:
    A list of dataframes corresponding to the length of monthly urls supplied as input.
    
    Example usage:
    ufo_scrape_L2(urls)
    ufo_scrape_L2(['http://www.nuforc.org/webreports/'+k for k in url_dict_L1.keys()])
    """
    dfs = []
    for monthly_url in monthly_urls:
        monthly_ufo_page = http.get(monthly_url)
        
        df = pd.read_html(monthly_ufo_page.content)[0] # The table of interest is always the first table element
        
        # Acquire urls for each sighting in a month
        sighting_urls=[]
        for tr in BeautifulSoup(monthly_ufo_page.content, 'html.parser').find('tbody').find_all('tr'):
            sighting_urls.append(tr.find('td').find('a')['href']) # Find the url for each sighting
        
        # Add URL and Full Summary columns to the dataframe
        df['URL'] = ['http://www.nuforc.org/webreports/' + url for url in sighting_urls] 
        df['Full Summary'] = df['URL'].map(lambda x: nuforc_scrape_L3(x)) # Get full summary for each sighting
        
        dfs.append(df)
    return dfs # return list of dataframes

# %%
def nuforc_scrape_L3(url):
    """
    Takes a report url and returns the full report sighting summary description. Protects against
    empty or missing webpages, providing diagnostic information in these cases.
    """
    page = http.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    # Extract full summary description
    try:
        if page:
            desc = soup.find('tbody').find_all('td')[1].text
            return desc
        else: # Handle missing webpage (Posting date of 5/4/19 has numerous examples)
            return '[[The page cannot be found]]'
    except: # Handle incomplete/empty webpages
        return url # Use corresponding url to examine these pages if needed

# %% [markdown]
# Next, a 'brief' demo will run on the two most recent months. A note of caution: running the scrape on full list of month/year url pairs will likely take at least several hours.

# %%
a = time.time()
df_list = nuforc_scrape_L2(urls[0:2]) # 2 most recent month/year tables worth of UFO reports
b = time.time()
b-a # time elapsed, in seconds
# Out:
# 344.32057666778564

# %%
# If many dataframes are present in the resulting list, one could combine the dataframes like so:
ufo_df = df_list[0]
for i in df_list[1:len(df_list)]:
    ufo_df = pd.concat([ufo_df, i])
ufo_df
# Out:
#       Date / Time                 City State      Shape       Duration  \
# 0    9/4/20 05:36              Buffalo    NY      Other        Unknown
# 1    9/4/20 04:58             Lakeland    FL   Fireball      4 seconds
# 2    9/4/20 03:20          York County    VA      Other    1-2 seconds
# 3    9/4/20 03:18  Beausejour (Canada)    MB  Formation      5 seconds
# 4    9/4/20 01:15              Pahrump    NV      Light    2-3 minutes
# ..            ...                  ...   ...        ...            ...
# 646  8/1/20 04:00            Lehighton    PA      Light     60 minutes
# 647  8/1/20 04:00             N. Wales    PA    Chevron     30 minutes
# 648  8/1/20 03:04            Melbourne    FL       Oval      6 minutes
# 649  8/1/20 01:10            Big Falls    MN   Triangle      3 seconds
# 650  8/1/20 00:00             Portland    OR      Light  30-40 seconds
#
#                                                Summary  Posted  \
# 0    The shape consisted of two chevrons with a ver...  9/4/20
# 1    Bright Falling Green Object In A Moonlit Early...  9/4/20
# 2    I was heading back from a friends house coming...  9/4/20
# 3        3 white dots flying East ward in Eastern sky.  9/4/20
# 4    Blue ziggzaging and sudden stops light that ti...  9/4/20
# ..                                                 ...     ...
# 646  This is the 3rd experiences I've had in a 4-5 ...  8/6/20
# 647  Three bright lights in the sky that disappeare...  8/6/20
# 648  I don't know what this is. If you could confor...  8/6/20
# 649  I was sitting on my back porch smoking, when I...  8/6/20
# 650                   Saw light round object hovering.  8/6/20
#
#                                                    URL  \
# 0    http://www.nuforc.org/webreports/159/S159151.html
# 1    http://www.nuforc.org/webreports/159/S159152.html
# 2    http://www.nuforc.org/webreports/159/S159147.html
# 3    http://www.nuforc.org/webreports/159/S159154.html
# 4    http://www.nuforc.org/webreports/159/S159153.html
# ..                                                 ...
# 646  http://www.nuforc.org/webreports/158/S158093.html
# 647  http://www.nuforc.org/webreports/158/S158153.html
# 648  http://www.nuforc.org/webreports/158/S158088.html
# 649  http://www.nuforc.org/webreports/158/S158100.html
# 650  http://www.nuforc.org/webreports/158/S158160.html
#
#                                           Full Summary
# 0    The shape consisted of two chevrons with a ver...
# 1    Bright Falling Green Object In A Moonlit Early...
# 2    I was heading back from a friends house coming...
# 3    3 white dots flying East ward in Eastern sky3 ...
# 4    Blue ziggzaging and sudden stops light that ti...
# ..                                                 ...
# 646  This is the 3rd experiences I've had in a 4-5 ...
# 647  Three bright lights in the sky that disappeare...
# 648  I don't know what this is. If you could confor...
# 649  I was sitting on my back porch smoking, when I...
# 650  Saw light round object hovering.My wife and I ...
#
# [682 rows x 9 columns]

# %%
# Finally, the results can be saved with the following: tailor the filename to represent the timeframe captured
dates = '2020_09_08'
ufo_df.to_csv('nuforc_reports_'+dates+'.csv', index=False)
